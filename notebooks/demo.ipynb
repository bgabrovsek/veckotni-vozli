# %%
import piplite
await piplite.install("numpy")
await piplite.install("matplotlib")

from veckotni import *

# Generiraj naključen večkoten vozel.
v = nakljucen_vozel(10)
# Prikaži
print(v)
v.prikazi()

print("Zmanjševanje vozla s trikotniškimi premiki")

v.reduciraj()

print(v)
v.prikazi()

# %%
# Poičimo vozel, ki ga ni mogoče reducirati z manj kot 6 križišči (deteljica)
deteljica = poisci_reduciran_vozel(10, 6)
deteljica.prikazi()

# %%
# Generirajmo torusni vozel s 100 križišči
v = torusni_vozel(100, 3, 2)
v.prikazi()
print("Zmanjševanje vozla s trikotniškimi premiki")
v.reduciraj()
print(v)
v.prikazi()
